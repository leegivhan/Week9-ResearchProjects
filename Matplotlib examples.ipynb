# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
import csv
#CSV from Washington Post
df = pd.read_csv('fatal-police-shootings-data.csv')
# race = df['race']

# race_group = df.groupby('race')['race'].count()
race_group = df.groupby('race').size().plot(kind="pie", explode=[0, 0, 0, 0, 0, 0.05], figsize=(10, 10))

# sums = df.race_group.sum()
# axis('equal');
# pie(sums, labels=sums.index);

# fig1, ax1 = plt.subplots()
# ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
#         shadow=True, startangle=90)
# ax1.axis('equal')
# colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
# sums=df.groupby(df[race]).sum()
# plt.pie(race, labels=x)

# races = 'Asian', 'Black', 'Hispanic', 'Native American', 'Other', 'White'
# killed = [96, 1415, 994, 82, 47, 2719]

# ro = pd.DataFrame({'races': ['Asian', 'Black', 'Hispanic', 'Native American', 'Other', 'White'],
#                   'killed': [96, 1415, 994, 82, 47, 2719]})

# ro.killed.groupby(ro.races).sum().plot(kind='pie')
# plt.axis('equal')

# fig1, ax1 = plt.subplots()
# ax1.pie(killed, races=races, autopct='%1.1f%%',
#         shadow=True, startangle=90)
# ax1.axis('equal')

plt.show()
# print(race_group.values)

print(race_group)
# Out:
# AxesSubplot(0.135,0.125;0.755x0.755)

# %%
quotient1 = 2719/250500000
percentage1 = quotient1 * 100
format_pw = "{:.3f}".format(percentage1)
print(f'Percentage of white people killed by police since 2015 (of total white population in USA): {format_pw}')
w = pd.DataFrame({'killed': [2719], 'population': [250500000]})
# Out:
# Percentage of white people killed by police since 2015 (of total white population in USA): 0.001

# %%
quotient3 = 994/60480000
percentage3 = quotient3 * 100
format_ph = "{:.3f}".format(percentage3)
print(f'Percentage of hispanic people killed by police since 2015 (of total white population in USA): {format_ph}')
# Out:
# Percentage of hispanic people killed by police since 2015 (of total white population in USA): 0.002

# %%
quotient2 = 1415/42000000
percentage2 = quotient2 * 100
format_pb = "{:.3f}".format(percentage2)
print(f'Percentage of black people killed by police since 2015 (of total black population in USA): {format_pb}')
# Out:
# Percentage of black people killed by police since 2015 (of total black population in USA): 0.003

# %%
format_t = "{:.0f}".format(percentage2/percentage1)
print(f'Blacks {format_t} times more likely than whites to be killed by the police in America.')
# Out:
# Blacks 3 times more likely than whites to be killed by the police in America.

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

races = ('Black', 'Hispanic', 'White')
y_pos = np.arange(0, 3)
percentage = [float(format_pb), float(format_ph), float(format_pw)]

plt.bar(y_pos, percentage, align='center', alpha=0.5)
plt.xticks(y_pos, races)
plt.ylabel('Likelihood to be killed by police')
plt.title('races')

plt.show()

# %%
import datetime
df['year'] = pd.DatetimeIndex(df['date']).year
df.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  longitude  latitude  is_geocoding_exact  year
# ...

# %%
race_year = df.groupby(['race', 'year']).agg({'race': ['count']})

# %%
print(race_year)
# Out:
#            race
#           count
# race year
# A    2015    14
#      2016    15
#      2017    16
#      2018    20
#      2019    19
#      2020    12
# B    2015   258
#      2016   234
#      2017   224
#      2018   229
#      2019   249
#      2020   221
# H    2015   172
#      2016   160
#      2017   181
#      2018   166
#      2019   163
#      2020   152
# N    2015     9
#      2016    16
#      2017    22
#      2018    15
#      2019    13
#      2020     7
# O    2015    14
#      2016    11
#      2017     6
#      2018     4
#      2019     9
#      2020     3
# W    2015   498
#      2016   469
#      2017   461
#      2018   456
#      2019   405
#      2020   430
